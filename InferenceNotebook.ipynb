# %%
from src.inference import Inference
from src.model import BasicBlock,ResNet,Bottleneck

# %%
infer = Inference()
# Out:
# No of params in model is  701466
# model is loaded on GPU: False

# %%
import PIL
import matplotlib.pyplot as plt
plt.imshow(PIL.Image.open("data/tmp_1185.jpg"))

# %%
infer("data/tmp_1185.jpg")
# Out:
# 'ship'
